# %% [markdown]
# #### Symbolic calculation of the speed of a bacteria under shear. The center of mass of the bacteria is the head center

# %%
from sympy import *

# %% [markdown]
# ## Force and torque on helix

# %% [markdown]
# Define symbols

# %%
#fluid velocity locally
Vfx, Vfy, Vfz, Vfluid = symbols("Vfx, Vfy, Vfz, Vfluid") 
#fluid vorticity locally
OmegaFluidx, OmegaFluidy, OmegaFluidz, OmegaFluid = symbols("OmegaFluidx, OmegaFluidy, OmegaFluidz, OmegaFluid") 

#friction
zetaRatio, zetaPara = symbols("zetaRatio, zetaPara")
#rotation rate of the head wrt to the lab
wHeadx, wHeady, wHeadz, wHead = symbols("wHeadx, wHeady, wHeadz, wHead")
#speed of the head wrt to the lab
vHeadx, vHeady, vHeadz, vHead = symbols("vHeadx, vHeady, vHeadz, vHead")
#position of a point on helix wrt to helix center
rHelixx, rHelixy, rHelixz, rHelix = symbols("rHelixx, rHelixy, rHelixz, rHelix")
#deformation velocity of helix
vdHelixx, vdHelixy, vdHelixz, vdHelix = symbols("vdHelixx, vdHelixy, vdHelixz, vdHelix")
#vector from helix center to beginning of head
deltaRHelixx, deltaRHelixy, deltaRHelixz, deltaRHelix = symbols("deltaRHelixx, deltaRHelixy, deltaRHelixz, deltaRHelix ")
#vector from head center to beginning of helix
deltaRHeadx, deltaRHeady, deltaRHeadz, deltaRHead = symbols("deltaRHeadx, deltaRHeady, deltaRHeadz, deltaRHead")

#velocity of a point on the helix wrt to the lab
vPointHelixx, vPointHelixy, vPointHelixz, vPointHelix = symbols("vPointHelixx, vPointHelixy, vPointHelixz, vPointHelix") 

#relative speed between helix and fluid
vRelx, vRely, vRelz, vRel = symbols("vRelx, vRely, vRelz, vRel")
#parallel component of relative speed
vRelParallelx, vRelParallely, vRelParallelz, vRelParallel = symbols("vRelParallelx, vRelParallely, vRelParallelz, vRelParallel")
#tangent vector at helix point
tx, ty, tz, t = symbols("tx, ty, tz, t")
#force on helix
FHelixx, FHelixy, FHelixz, FHelix = symbols("FHelixx, FHelixy, FHelixz, FHelix")
#torque on helix
MHelixx, MHelixy, MHelixz, MHelix = symbols("MHelixx, MHelixy, MHelixz, MHelix")
FMMatHelix = symbols("FMMatHelix")

# %% [markdown]
# Create matrices

# %%
Vfluid = Matrix([Vfx, Vfy, Vfz]) #fluid velocity
OmegaFluid = Matrix([OmegaFluidx, OmegaFluidy, OmegaFluidz]) #fluid vorticity

wHead = Matrix([wHeadx, wHeady, wHeadz]) #head rotation rate
vHead = Matrix([vHeadx, vHeady, vHeadz]) #head speed
rHelix = Matrix([rHelixx, rHelixy, rHelixz]) #position of point on helix wrt helix center
vdHelix = Matrix([vdHelixx, vdHelixy, vdHelixz]) #deformation velocity of helix
deltaRHead = Matrix([deltaRHeadx, deltaRHeady, deltaRHeadz]) #vector from head center to beginning of helix
deltaRHelix = Matrix([deltaRHelixx, deltaRHelixy, deltaRHelixz]) #hector from helix center to beginning of head
vPointHelix = Matrix([vPointHelixx, vPointHelixy, vPointHelixz]) 

vRel = Matrix([vRelx, vRely, vRelz])
vRelParallel = Matrix([vRelParallelx, vRelParallely, vRelParallelz])

t = Matrix([tx, ty, tz]) #tangent vector
FHelix = Matrix([FHelixx, FHelixy, FHelixz]) #force on helix
MHelix = Matrix([MHelixx, MHelixy, MHelixz]) #torque

# %% [markdown]
# Define the physics

# %%
vPointHelix = vdHelix + vHead + wHead.cross(rHelix + deltaRHead - deltaRHelix) #deltaRHead - deltaRHelix = vector from center of head to center of helix

vRel = Vfluid - vPointHelix
vRelParallel = vRel.dot(t)*t

FHelix = zetaPara*(zetaRatio*vRel + (1-zetaRatio)*vRelParallel)
MHelix = (rHelix + deltaRHead - deltaRHelix).cross(FHelix) #calculated from the center of torque : deltaRHead - deltaRHelix = vector from center of head to center of helix

FMMatHelix = FHelix.col_join(MHelix)

# %% [markdown]
# ### Sum forces and torques on Helix and get the equations

# %%
eqnsHelix = [FMMatHelix[0].expand(basic=True),FMMatHelix[1].expand(basic=True),FMMatHelix[2].expand(basic=True),FMMatHelix[3].expand(basic=True),FMMatHelix[4].expand(basic=True),FMMatHelix[5].expand(basic=True)]

zetaMatHelix,AHelix = linear_eq_to_matrix(eqnsHelix, [vHeadx, vHeady, vHeadz, wHeadx, wHeady, wHeadz])

# %%
zetaMatHelix
# Out:
# Matrix([
# [                                                                                                                                                                                                                                                                                                                                                                                                                                            tx**2*zetaPara*zetaRatio - tx**2*zetaPara - zetaPara*zetaRatio,                                                                                                                                                                                                                                                                                                                                                                                                                                                                 tx*ty*zetaPara*zetaRatio - tx*ty*zetaPara,                                                                                                                                                                                                                                                                                                                                                                                                                                                                  tx*tz*zetaPara*zetaRatio - tx*tz*zetaPara,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                 tx*ty*zetaPara*zetaRatio - tx*ty*zetaPara,                                                                                                                                                                                                                                                                                                                                                                                                                                            ty**2*zetaPara*zetaRatio - ty**2*zetaPara - zetaPara*zetaRatio,                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ty*tz*zetaPara*zetaRatio - ty*tz*zetaPara,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                 tx*tz*zetaPara*zetaRatio - tx*tz*zetaPara,                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ty*tz*zetaPara*zetaRatio - ty*tz*zetaPara,                                                                                                                                                                                                                                                                                                                                                                                                                                             tz**2*zetaPara*zetaRatio - tz**2*zetaPara - zetaPara*zetaRatio,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# [                                                                                                 deltaRHeady*tx*tz*zetaPara*zetaRatio - deltaRHeady*tx*tz*zetaPara - deltaRHeadz*tx*ty*zetaPara*zetaRatio + deltaRHeadz*tx*ty*zetaPara - deltaRHelixy*tx*tz*zetaPara*zetaRatio + deltaRHelixy*tx*tz*zetaPara + deltaRHelixz*tx*ty*zetaPara*zetaRatio - deltaRHelixz*tx*ty*zetaPara + rHelixy*tx*tz*zetaPara*zetaRatio - rHelixy*tx*tz*zetaPara - rHelixz*tx*ty*zetaPara*zetaRatio + rHelixz*tx*ty*zetaPara, deltaRHeady*ty*tz*zetaPara*zetaRatio - deltaRHeady*ty*tz*zetaPara - deltaRHeadz*ty**2*zetaPara*zetaRatio + deltaRHeadz*ty**2*zetaPara + deltaRHeadz*zetaPara*zetaRatio - deltaRHelixy*ty*tz*zetaPara*zetaRatio + deltaRHelixy*ty*tz*zetaPara + deltaRHelixz*ty**2*zetaPara*zetaRatio - deltaRHelixz*ty**2*zetaPara - deltaRHelixz*zetaPara*zetaRatio + rHelixy*ty*tz*zetaPara*zetaRatio - rHelixy*ty*tz*zetaPara - rHelixz*ty**2*zetaPara*zetaRatio + rHelixz*ty**2*zetaPara + rHelixz*zetaPara*
*ty*tz*zetaPara*zetaRatio - Vfz*rHelixx*ty*tz*zetaPara - Vfz*rHelixy*tx*tz*zetaPara*zetaRatio + Vfz*rHelixy*tx*tz*zetaPara - deltaRHeadx*tx*ty*vdHelixx*zetaPara*zetaRatio + deltaRHeadx*tx*ty*vdHelixx*zetaPara - deltaRHeadx*ty**2*vdHelixy*zetaPara*zetaRatio + deltaRHeadx*ty**2*vdHelixy*zetaPara - deltaRHeadx*ty*tz*vdHelixz*zetaPara*zetaRatio + deltaRHeadx*ty*tz*vdHelixz*zetaPara + deltaRHeadx*vdHelixy*zetaPara*zetaRatio + deltaRHeady*tx**2*vdHelixx*zetaPara*zetaRatio - deltaRHeady*tx**2*vdHelixx*zetaPara + deltaRHeady*tx*ty*vdHelixy*zetaPara*zetaRatio - deltaRHeady*tx*ty*vdHelixy*zetaPara + deltaRHeady*tx*tz*vdHelixz*zetaPara*zetaRatio - deltaRHeady*tx*tz*vdHelixz*zetaPara - deltaRHeady*vdHelixx*zetaPara*zetaRatio + deltaRHelixx*tx*ty*vdHelixx*zetaPara*zetaRatio - deltaRHelixx*tx*ty*vdHelixx*zetaPara + deltaRHelixx*ty**2*vdHelixy*zetaPara*zetaRatio - deltaRHelixx*ty**2*vdHelixy*zetaPara + deltaRHelixx*ty*tz*vdHelixz*zetaPara*zetaRatio - deltaRHelixx*ty*tz*vdHelixz*zetaPara - deltaRHelixx*vdHelixy*zetaPara*zetaRatio - deltaRHelixy*tx**2*vdHelixx*zetaPara*zetaRatio + deltaRHelixy*tx**2*vdHelixx*zetaPara - deltaRHelixy*tx*ty*vdHelixy*zetaPara*zetaRatio + deltaRHelixy*tx*ty*vdHelixy*zetaPara - deltaRHelixy*tx*tz*vdHelixz*zetaPara*zetaRatio + deltaRHelixy*tx*tz*vdHelixz*zetaPara + deltaRHelixy*vdHelixx*zetaPara*zetaRatio - rHelixx*tx*ty*vdHelixx*zetaPara*zetaRatio + rHelixx*tx*ty*vdHelixx*zetaPara - rHelixx*ty**2*vdHelixy*zetaPara*zetaRatio + rHelixx*ty**2*vdHelixy*zetaPara - rHelixx*ty*tz*vdHelixz*zetaPara*zetaRatio + rHelixx*ty*tz*vdHelixz*zetaPara + rHelixx*vdHelixy*zetaPara*zetaRatio + rHelixy*tx**2*vdHelixx*zetaPara*zetaRatio - rHelixy*tx**2*vdHelixx*zetaPara + rHelixy*tx*ty*vdHelixy*zetaPara*zetaRatio - rHelixy*tx*ty*vdHelixy*zetaPara + rHelixy*tx*tz*vdHelixz*zetaPara*zetaRatio - rHelixy*tx*tz*vdHelixz*zetaPara - rHelixy*vdHelixx*zetaPara*zetaRatio]])

# %% [markdown]
# ## Force and Torque on Head, general flow

# %% [markdown]
# Define symbols

# %%
xHead, yHead, zHead, posHead = symbols("xHead, yHead, zHead, posHead")
FHeadx, FHeady, FHeadz, FHead = symbols("FHeadx, FHeady, FHeadz, FHead")
MHeadx, MHeady, MHeadz, MHead = symbols("MHeadx, MHeady, MHeadz, MHead")
vHeadRelx, vHeadRely, vHeadRelz, vHeadRel = symbols("vHeadRelx, vHeadRely, vHeadRelz, vHeadRel")

CfHead, CmHead = symbols("CfHead, CmHead")
mu, a = symbols("mu, a")

# %% [markdown]
# Create matrices

# %%
vHeadRel = Matrix([vHeadRelx, vHeadRely, vHeadRelz])

FHead = Matrix([FHeadx, FHeady, FHeadz]) #force on head
MHead = Matrix([MHeadx, MHeady, MHeadz]) #torque
posHead = Matrix([xHead, yHead, zHead]) #position of head in the lab frame

# %% [markdown]
# Define the physics

# %%
vHeadRel = Vfluid - vHead

CfHead = 6*pi*mu*a
CmHead = 8*pi*mu*a**3

FHead = CfHead*vHeadRel
MHead = - CmHead*wHead + CmHead*1/2*Matrix([OmegaFluidx,OmegaFluidy,OmegaFluidz]) #+ deltaRHead.cross(FHead)

FMMatHead = FHead.col_join(MHead)

# %% [markdown]
# ### Get the equations for the head

# %%
eqnsHead = [FMMatHead[0].expand(basic=True),FMMatHead[1].expand(basic=True),FMMatHead[2].expand(basic=True),FMMatHead[3].expand(basic=True),FMMatHead[4].expand(basic=True),FMMatHead[5].expand(basic=True)]

zetaMatHead,AHead = linear_eq_to_matrix(eqnsHead, [vHeadx, vHeady, vHeadz, wHeadx, wHeady, wHeadz])

# %%
zetaMatHead
# Out:
# Matrix([
# [-6*pi*a*mu,          0,          0,             0,             0,             0],
# [         0, -6*pi*a*mu,          0,             0,             0,             0],
# [         0,          0, -6*pi*a*mu,             0,             0,             0],
# [         0,          0,          0, -8*pi*a**3*mu,             0,             0],
# [         0,          0,          0,             0, -8*pi*a**3*mu,             0],
# [         0,          0,          0,             0,             0, -8*pi*a**3*mu]])

# %%
AHead
# Out:
# Matrix([
# [           -6*pi*Vfx*a*mu],
# [           -6*pi*Vfy*a*mu],
# [           -6*pi*Vfz*a*mu],
# [-4*pi*OmegaFluidx*a**3*mu],
# [-4*pi*OmegaFluidy*a**3*mu],
# [-4*pi*OmegaFluidz*a**3*mu]])

# %% [markdown]
# ### Write this in LateX

# %%
print(latex(AHead, mode='equation'))   # prints '$1 + {2}^{x + y}$'

# %%
print(latex(zetaMatHead, mode='equation'))   # prints '$1 + {2}^{x + y}$'

# %%
print(latex(zetaMatHelix, mode='equation'))   # prints '$1 + {2}^{x + y}$'

# %%
print(latex(simplify(zetaMatHelix), mode='equation'))

# %%
for i in range(6):
    for j in range(6):
        print(str(i) + str(j) + '=' + latex(simplify(zetaMatHelix[i,j]), mode='equation'))

# %%
for i in range(6):
        print(str(i) + '=' + latex(simplify(AHelix[i]), mode='equation'))
# Out:
# 0=\begin{equation}zetaPara \left(Vfx tx^{2} zetaRatio - Vfx tx^{2} - Vfx zetaRatio + Vfy tx ty zetaRatio - Vfy tx ty + Vfz tx tz zetaRatio - Vfz tx tz - tx^{2} vdHelixx zetaRatio + tx^{2} vdHelixx - tx ty vdHelixy zetaRatio + tx ty vdHelixy - tx tz vdHelixz zetaRatio + tx tz vdHelixz + vdHelixx zetaRatio\right)\end{equation}
# 1=\begin{equation}zetaPara \left(Vfx tx ty zetaRatio - Vfx tx ty + Vfy ty^{2} zetaRatio - Vfy ty^{2} - Vfy zetaRatio + Vfz ty tz zetaRatio - Vfz ty tz - tx ty vdHelixx zetaRatio + tx ty vdHelixx - ty^{2} vdHelixy zetaRatio + ty^{2} vdHelixy - ty tz vdHelixz zetaRatio + ty tz vdHelixz + vdHelixy zetaRatio\right)\end{equation}
# 2=\begin{equation}zetaPara \left(Vfx tx tz zetaRatio - Vfx tx tz + Vfy ty tz zetaRatio - Vfy ty tz + Vfz tz^{2} zetaRatio - Vfz tz^{2} - Vfz zetaRatio - tx tz vdHelixx zetaRatio + tx tz vdHelixx - ty tz vdHelixy zetaRatio + ty tz vdHelixy - tz^{2} vdHelixz zetaRatio + tz^{2} vdHelixz + vdHelixz zetaRatio\right)\end{equation}
# 3=\begin{equation}zetaPara \left(Vfx deltaRHeady tx tz zetaRatio - Vfx deltaRHeady tx tz - Vfx deltaRHeadz tx ty zetaRatio + Vfx deltaRHeadz tx ty - Vfx deltaRHelixy tx tz zetaRatio + Vfx deltaRHelixy tx tz + Vfx deltaRHelixz tx ty zetaRatio - Vfx deltaRHelixz tx ty + Vfx rHelixy tx tz zetaRatio - Vfx rHelixy tx tz - Vfx rHelixz tx ty zetaRatio + Vfx rHelixz tx ty + Vfy deltaRHeady ty tz zetaRatio - Vfy deltaRHeady ty tz - Vfy deltaRHeadz ty^{2} zetaRatio + Vfy deltaRHeadz ty^{2} + Vfy deltaRHeadz zetaRatio - Vfy deltaRHelixy ty tz zetaRatio + Vfy deltaRHelixy ty tz + Vfy deltaRHelixz ty^{2} zetaRatio - Vfy deltaRHelixz ty^{2} - Vfy deltaRHelixz zetaRatio + Vfy rHelixy ty tz zetaRatio - Vfy rHelixy ty tz - Vfy rHelixz ty^{2} zetaRatio + Vfy rHelixz ty^{2} + Vfy rHelixz zetaRatio + Vfz deltaRHeady tz^{2} zetaRatio - Vfz deltaRHeady tz^{2} - Vfz deltaRHeady zetaRatio - Vfz deltaRHeadz ty tz zetaRatio + Vfz deltaRHeadz ty tz - Vfz deltaRHelixy tz^{2} zetaRatio + Vfz deltaRHelixy tz^{2} + Vfz deltaRHelixy zetaRatio + Vfz deltaRHelixz ty tz zetaRatio - Vfz deltaRHelixz ty tz + Vfz rHelixy tz^{2} zetaRatio - Vfz rHelixy tz^{2} - Vfz rHelixy zetaRatio - Vfz rHelixz ty tz zetaRatio + Vfz rHelixz ty tz - deltaRHeady tx tz vdHelixx zetaRatio + deltaRHeady tx tz vdHelixx - deltaRHeady ty tz vdHelixy zetaRatio + deltaRHeady ty tz vdHelixy - deltaRHeady tz^{2} vdHelixz zetaRatio + deltaRHeady tz^{2} vdHelixz + deltaRHeady vdHelixz zetaRatio + deltaRHeadz tx ty vdHelixx zetaRatio - deltaRHeadz tx ty vdHelixx + deltaRHeadz ty^{2} vdHelixy zetaRatio - deltaRHeadz ty^{2} vdHelixy + deltaRHeadz ty tz vdHelixz zetaRatio - deltaRHeadz ty tz vdHelixz - deltaRHeadz vdHelixy zetaRatio + deltaRHelixy tx tz vdHelixx zetaRatio - deltaRHelixy tx tz vdHelixx + deltaRHelixy ty tz vdHelixy zetaRatio - deltaRHelixy ty tz vdHelixy + deltaRHelixy tz^{2} vdHelixz zetaRatio - deltaRHelixy tz^{2} vdHelixz - deltaRHelixy vdHelixz zetaRatio - deltaRHelixz tx ty vdHelixx zetaRatio + deltaRHelixz tx ty vdHelixx - deltaRHelixz ty^{2} vdHelixy zetaRatio + deltaRHelixz ty^{2} vdHelixy - deltaRHelixz ty tz vdHelixz zetaRatio + deltaRHelixz ty tz vdHelixz + deltaRHelixz vdHelixy zetaRatio - rHelixy tx tz vdHelixx zetaRatio + rHelixy tx tz vdHelixx - rHelixy ty tz vdHelixy zetaRatio + rHelixy ty tz vdHelixy - rHelixy tz^{2} vdHelixz zetaRatio + rHelixy tz^{2} vdHelixz + rHelixy vdHelixz zetaRatio + rHelixz tx ty vdHelixx zetaRatio - rHelixz tx ty vdHelixx + rHelixz ty^{2} vdHelixy zetaRatio - rHelixz ty^{2} vdHelixy + rHelixz ty tz vdHelixz zetaRatio - rHelixz ty tz vdHelixz - rHelixz vdHelixy zetaRatio\right)\end{equation}
# 4=\begin{equation}zetaPara \left(- Vfx deltaRHeadx tx tz zetaRatio + Vfx deltaRHeadx tx tz + Vfx deltaRHeadz tx^{2} zetaRatio - Vfx deltaRHeadz tx^{2} - Vfx deltaRHeadz zetaRatio + Vfx deltaRHelixx tx tz zetaRatio - Vfx deltaRHelixx tx tz - Vfx deltaRHelixz tx^{2} zetaRatio + Vfx deltaRHelixz tx^{2} + Vfx deltaRHelixz zetaRatio - Vfx rHelixx tx tz zetaRatio + Vfx rHelixx tx tz + Vfx rHelixz tx^{2} zetaRatio - Vfx rHelixz tx^{2} - Vfx rHelixz zetaRatio - Vfy deltaRHeadx ty tz zetaRatio + Vfy deltaRHeadx ty tz + Vfy deltaRHeadz tx ty zetaRatio - Vfy deltaRHeadz tx ty + Vfy deltaRHelixx ty tz zetaRatio - Vfy deltaRHelixx ty tz - Vfy deltaRHelixz tx ty zetaRatio + Vfy deltaRHelixz tx ty - Vfy rHelixx ty tz zetaRatio + Vfy rHelixx ty tz + Vfy rHelixz tx ty zetaRatio - Vfy rHelixz tx ty - Vfz deltaRHeadx tz^{2} zetaRatio + Vfz deltaRHeadx tz^{2} + Vfz deltaRHeadx zetaRatio + Vfz deltaRHeadz tx tz zetaRatio - Vfz deltaRHeadz tx tz + Vfz deltaRHelixx tz^{2} zetaRatio - Vfz deltaRHelixx tz^{2} - Vfz deltaRHelixx zetaRatio - Vfz deltaRHelixz tx tz zetaRatio + Vfz deltaRHelixz tx tz - Vfz rHelixx tz^{2} zetaRatio + Vfz rHelixx tz^{2} + Vfz rHelixx zetaRatio + Vfz rHelixz tx tz zetaRatio - Vfz rHelixz tx tz + deltaRHeadx tx tz vdHelixx zetaRatio - deltaRHeadx tx tz vdHelixx + deltaRHeadx ty tz vdHelixy zetaRatio - deltaRHeadx ty tz vdHelixy + deltaRHeadx tz^{2} vdHelixz zetaRatio - deltaRHeadx tz^{2} vdHelixz - deltaRHeadx vdHelixz zetaRatio - deltaRHeadz tx^{2} vdHelixx zetaRatio + deltaRHeadz tx^{2} vdHelixx - deltaRHeadz tx ty vdHelixy zetaRatio + deltaRHeadz tx ty vdHelixy - deltaRHeadz tx tz vdHelixz zetaRatio + deltaRHeadz tx tz vdHelixz + deltaRHeadz vdHelixx zetaRatio - deltaRHelixx tx tz vdHelixx zetaRatio + deltaRHelixx tx tz vdHelixx - deltaRHelixx ty tz vdHelixy zetaRatio + deltaRHelixx ty tz vdHelixy - deltaRHelixx tz^{2} vdHelixz zetaRatio + deltaRHelixx tz^{2} vdHelixz + deltaRHelixx vdHelixz zetaRatio + deltaRHelixz tx^{2} vdHelixx zetaRatio - deltaRHelixz tx^{2} vdHelixx + deltaRHelixz tx ty vdHelixy zetaRatio - deltaRHelixz tx ty vdHelixy + deltaRHelixz tx tz vdHelixz zetaRatio - deltaRHelixz tx tz vdHelixz - deltaRHelixz vdHelixx zetaRatio + rHelixx tx tz vdHelixx zetaRatio - rHelixx tx tz vdHelixx + rHelixx ty tz vdHelixy zetaRatio - rHelixx ty tz vdHelixy + rHelixx tz^{2} vdHelixz zetaRatio - rHelixx tz^{2} vdHelixz - rHelixx vdHelixz zetaRatio - rHelixz tx^{2} vdHelixx zetaRatio + rHelixz tx^{2} vdHelixx - rHelixz tx ty vdHelixy zetaRatio + rHelixz tx ty vdHelixy - rHelixz tx tz vdHelixz zetaRatio + rHelixz tx tz vdHelixz + rHelixz vdHelixx zetaRatio\right)\end{equation}
# 5=\begin{equation}zetaPara \left(Vfx deltaRHeadx tx ty zetaRatio - Vfx deltaRHeadx tx ty - Vfx deltaRHeady tx^{2} zetaRatio + Vfx deltaRHeady tx^{2} + Vfx deltaRHeady zetaRatio - Vfx deltaRHelixx tx ty zetaRatio + Vfx deltaRHelixx tx ty + Vfx deltaRHelixy tx^{2} zetaRatio - Vfx deltaRHelixy tx^{2} - Vfx deltaRHelixy zetaRatio + Vfx rHelixx tx ty zetaRatio - Vfx rHelixx tx ty - Vfx rHelixy tx^{2} zetaRatio + Vfx rHelixy tx^{2} + Vfx rHelixy zetaRatio + Vfy deltaRHeadx ty^{2} zetaRatio - Vfy deltaRHeadx ty^{2} - Vfy deltaRHeadx zetaRatio - Vfy deltaRHeady tx ty zetaRatio + Vfy deltaRHeady tx ty - Vfy deltaRHelixx ty^{2} zetaRatio + Vfy deltaRHelixx ty^{2} + Vfy deltaRHelixx zetaRatio + Vfy deltaRHelixy tx ty zetaRatio - Vfy deltaRHelixy tx ty + Vfy rHelixx ty^{2} zetaRatio - Vfy rHelixx ty^{2} - Vfy rHelixx zetaRatio - Vfy rHelixy tx ty zetaRatio + Vfy rHelixy tx ty + Vfz deltaRHeadx ty tz zetaRatio - Vfz deltaRHeadx ty tz - Vfz deltaRHeady tx tz zetaRatio + Vfz deltaRHeady tx tz - Vfz deltaRHelixx ty tz zetaRatio + Vfz deltaRHelixx ty tz + Vfz deltaRHelixy tx tz zetaRatio - Vfz deltaRHelixy tx tz + Vfz rHelixx ty tz zetaRatio - Vfz rHelixx ty tz - Vfz rHelixy tx tz zetaRatio + Vfz rHelixy tx tz - deltaRHeadx tx ty vdHelixx zetaRatio + deltaRHeadx tx ty vdHelixx - deltaRHeadx ty^{2} vdHelixy zetaRatio + deltaRHeadx ty^{2} vdHelixy - deltaRHeadx ty tz vdHelixz zetaRatio + deltaRHeadx ty tz vdHelixz + deltaRHeadx vdHelixy zetaRatio + deltaRHeady tx^{2} vdHelixx zetaRatio - deltaRHeady tx^{2} vdHelixx + deltaRHeady tx ty vdHelixy zetaRatio - deltaRHeady tx ty vdHelixy + deltaRHeady tx tz vdHelixz zetaRatio - deltaRHeady tx tz vdHelixz - deltaRHeady vdHelixx zetaRatio + deltaRHelixx tx ty vdHelixx zetaRatio - deltaRHelixx tx ty vdHelixx + deltaRHelixx ty^{2} vdHelixy zetaRatio - deltaRHelixx ty^{2} vdHelixy + deltaRHelixx ty tz vdHelixz zetaRatio - deltaRHelixx ty tz vdHelixz - deltaRHelixx vdHelixy zetaRatio - deltaRHelixy tx^{2} vdHelixx zetaRatio + deltaRHelixy tx^{2} vdHelixx - deltaRHelixy tx ty vdHelixy zetaRatio + deltaRHelixy tx ty vdHelixy - deltaRHelixy tx tz vdHelixz zetaRatio + deltaRHelixy tx tz vdHelixz + deltaRHelixy vdHelixx zetaRatio - rHelixx tx ty vdHelixx zetaRatio + rHelixx tx ty vdHelixx - rHelixx ty^{2} vdHelixy zetaRatio + rHelixx ty^{2} vdHelixy - rHelixx ty tz vdHelixz zetaRatio + rHelixx ty tz vdHelixz + rHelixx vdHelixy zetaRatio + rHelixy tx^{2} vdHelixx zetaRatio - rHelixy tx^{2} vdHelixx + rHelixy tx ty vdHelixy zetaRatio - rHelixy tx ty vdHelixy + rHelixy tx tz vdHelixz zetaRatio - rHelixy tx tz vdHelixz - rHelixy vdHelixx zetaRatio\right)\end{equation}

# %%
factor(AHelix[0])

# %% [markdown]
# ### Make assumptions on the flow to simplify all that

# %%
a0 = AHelix[0]
a1 = AHelix[1]
a2 = AHelix[2]
a3 = AHelix[3]
a4 = AHelix[4]
a5 = AHelix[5]

# %%
z0 = zetaMatHelix[0]
z1 = zetaMatHelix[1]
z2 = zetaMatHelix[2]
z3 = zetaMatHelix[3]
z4 = zetaMatHelix[4]
z5 = zetaMatHelix[5]

# %%
alpha, n, l, s, R, wRel = symbols("alpha, n, l, s, R, wRel")
gamma, y = symbols("gamma, y")

# %%
a0i = integrate(a0.subs({Vfz: gamma*R*sin(2*pi*s/l), Vfy:0, Vfx:0,
                         tx: -sin(alpha)*R*cos(2*pi*s/l), ty: sin(alpha)*R*sin(2*pi*s/l), tz: s*cos(alpha),
                         vdHelixx: -sin(alpha)*R*wRel*R*cos(2*pi*s/l),
                         vdHelixy: sin(alpha)*R*wRel*R*sin(2*pi*s/l),
                         vdHelixz: R*wRel*s*cos(alpha)}), (s, -l/2, l/2))

a1i = integrate(a1.subs({Vfz: gamma*R*sin(2*pi*s/l), Vfy:0, Vfx:0,
                         tx: -sin(alpha)*R*cos(2*pi*s/l), ty: sin(alpha)*R*sin(2*pi*s/l), tz: s*cos(alpha),
                         vdHelixx: -sin(alpha)*R*wRel*R*cos(2*pi*s/l),
                         vdHelixy: sin(alpha)*R*wRel*R*sin(2*pi*s/l),
                         vdHelixz: R*wRel*s*cos(alpha)}), (s, -l/2, l/2))

a2i = integrate(a2.subs({Vfz: gamma*R*sin(2*pi*s/l), Vfy:0, Vfx:0,
                         tx: -sin(alpha)*R*cos(2*pi*s/l), ty: sin(alpha)*R*sin(2*pi*s/l), tz: s*cos(alpha),
                         vdHelixx: -sin(alpha)*R*wRel*R*cos(2*pi*s/l),
                         vdHelixy: sin(alpha)*R*wRel*R*sin(2*pi*s/l),
                         vdHelixz: R*wRel*s*cos(alpha)}), (s, -l/2, l/2))

a3i = integrate(a3.subs({Vfz: gamma*R*sin(2*pi*s/l), Vfy:0, Vfx:0,
                         tx: -sin(alpha)*R*cos(2*pi*s/l), ty: sin(alpha)*R*sin(2*pi*s/l), tz: s*cos(alpha),
                         vdHelixx: -sin(alpha)*R*wRel*R*cos(2*pi*s/l),
                         vdHelixy: sin(alpha)*R*wRel*R*sin(2*pi*s/l),
                         vdHelixz: R*wRel*s*cos(alpha)}), (s, -l/2, l/2))

a4i = integrate(a4.subs({Vfz: gamma*R*sin(2*pi*s/l), Vfy:0, Vfx:0,
                         tx: -sin(alpha)*R*cos(2*pi*s/l), ty: sin(alpha)*R*sin(2*pi*s/l), tz: s*cos(alpha),
                         vdHelixx: -sin(alpha)*R*wRel*R*cos(2*pi*s/l),
                         vdHelixy: sin(alpha)*R*wRel*R*sin(2*pi*s/l),
                         vdHelixz: R*wRel*s*cos(alpha)}), (s, -l/2, l/2))

a5i = integrate(a5.subs({Vfz: gamma*R*sin(2*pi*s/l), Vfy:0, Vfx:0,
                         tx: -sin(alpha)*R*cos(2*pi*s/l), ty: sin(alpha)*R*sin(2*pi*s/l), tz: s*cos(alpha),
                         vdHelixx: -sin(alpha)*R*wRel*R*cos(2*pi*s/l),
                         vdHelixy: sin(alpha)*R*wRel*R*sin(2*pi*s/l),
                         vdHelixz: R*wRel*s*cos(alpha)}), (s, -l/2, l/2))

# %%
zi = integrate(zetaMatHelix.subs({Vfz: gamma*R*sin(2*pi*s/l), Vfy:0, Vfx:0,
                         tx: -sin(alpha)*R*cos(2*pi*s/l), ty: sin(alpha)*R*sin(2*pi*s/l), tz: s*cos(alpha),
                         vdHelixx: -sin(alpha)*R*wRel*R*cos(2*pi*s/l),
                         vdHelixy: sin(alpha)*R*wRel*R*sin(2*pi*s/l),
                         vdHelixz: R*wRel*s*cos(alpha)}), (s, -l/2, l/2))

# %%
ai = integrate(AHelix.subs({Vfz: gamma*R*sin(2*pi*s/l), Vfy:0, Vfx:0,
                         tx: -sin(alpha)*R*cos(2*pi*s/l), ty: sin(alpha)*R*sin(2*pi*s/l), tz: s*cos(alpha),
                         vdHelixx: -sin(alpha)*R*wRel*R*cos(2*pi*s/l),
                         vdHelixy: sin(alpha)*R*wRel*R*sin(2*pi*s/l),
                         vdHelixz: R*wRel*s*cos(alpha)}), (s, -l/2, l/2))

# %%
a0i.subs(l,1)
# Out:
# R**2*gamma*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(8*pi) - R**2*gamma*zetaPara*sin(alpha)*cos(alpha)/(8*pi) - R**2*wRel*zetaPara*zetaRatio*sin(alpha)*cos(alpha)**2/(2*pi**2) + R**2*wRel*zetaPara*sin(alpha)*cos(alpha)**2/(2*pi**2)

# %%
a1i.subs(l,1)
# Out:
# 0

# %%
a2i.subs(l,1)
# Out:
# 0

# %%
ai.subs(l,1)
# Out:
# Matrix([
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         R**2*gamma*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(8*pi) - R**2*gamma*zetaPara*sin(alpha)*cos(alpha)/(8*pi) - R**2*wRel*zetaPara*zetaRatio*sin(alpha)*cos(alpha)**2/(2*pi**2) + R**2*wRel*zetaPara*sin(alpha)*cos(alpha)**2/(2*pi**2)],
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0],
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0],
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0],
# [ R**2*deltaRHeadz*gamma*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(8*pi) - R**2*deltaRHeadz*gamma*zetaPara*sin(alpha)*cos(alpha)/(8*pi) - R**2*deltaRHeadz*wRel*zetaPara*zetaRatio*sin(alpha)*cos(alpha)**2/(2*pi**2) + R**2*deltaRHeadz*wRel*zetaPara*sin(alpha)*cos(alpha)**2/(2*pi**2) - R**2*deltaRHelixz*gamma*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(8*pi) + R**2*deltaRHelixz*gamma*zetaPara*sin(alpha)*cos(alpha)/(8*pi) + R**2*deltaRHelixz*wRel*zetaPara*zetaRatio*sin(alpha)*cos(alpha)**2/(2*pi**2) - R**2*deltaRHelixz*wRel*zetaPara*sin(alpha)*cos(alpha)**2/(2*pi**2) + R**2*gamma*rHelixz*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(8*pi) - R**2*gamma*rHelixz*zetaPara*sin(alpha)*cos(alpha)/(8*pi) - R**2*rHelixz*wRel*zetaPara*zetaRatio*sin(alpha)*cos(alpha)**2/(2*pi**2) + R**2*rHelixz*wRel*zetaPara*sin(alpha)*cos(alpha)**2/(2*pi**2)],
# [-R**2*deltaRHeady*gamma*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(8*pi) + R**2*deltaRHeady*gamma*zetaPara*sin(alpha)*cos(alpha)/(8*pi) + R**2*deltaRHeady*wRel*zetaPara*zetaRatio*sin(alpha)*cos(alpha)**2/(2*pi**2) - R**2*deltaRHeady*wRel*zetaPara*sin(alpha)*cos(alpha)**2/(2*pi**2) + R**2*deltaRHelixy*gamma*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(8*pi) - R**2*deltaRHelixy*gamma*zetaPara*sin(alpha)*cos(alpha)/(8*pi) - R**2*deltaRHelixy*wRel*zetaPara*zetaRatio*sin(alpha)*cos(alpha)**2/(2*pi**2) + R**2*deltaRHelixy*wRel*zetaPara*sin(alpha)*cos(alpha)**2/(2*pi**2) - R**2*gamma*rHelixy*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(8*pi) + R**2*gamma*rHelixy*zetaPara*sin(alpha)*cos(alpha)/(8*pi) + R**2*rHelixy*wRel*zetaPara*zetaRatio*sin(alpha)*cos(alpha)**2/(2*pi**2) - R**2*rHelixy*wRel*zetaPara*sin(alpha)*cos(alpha)**2/(2*pi**2)]])

# %%
zi
# Out:
# Matrix([
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           -R**2*zetaPara*zetaRatio*Piecewise((-l/2, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 + R**2*zetaPara*zetaRatio*Piecewise((l/2, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 + R**2*zetaPara*Piecewise((-l/2, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 - R**2*zetaPara*Piecewise((l/2, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 - l*zetaPara*zetaRatio,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    0,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 -R**2*zetaPara*zetaRatio*Piecewise((0, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 + R**2*zetaPara*zetaRatio*Piecewise((0, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 + R**2*zetaPara*Piecewise((0, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 - R**2*zetaPara*Piecewise((0, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 - l*zetaPara*zetaRatio,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                R*l**2*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(2*pi) - R*l**2*zetaPara*sin(alpha)*cos(alpha)/(2*pi),                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           R*l**2*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(2*pi) - R*l**2*zetaPara*sin(alpha)*cos(alpha)/(2*pi),                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        l**3*(zetaPara*zetaRatio*cos(alpha)**2/3 - zetaPara*cos(alpha)**2/3)/4 - l*zetaPara*zetaRatio,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0, R**2*deltaRHeadz*zetaPara*zetaRatio*Piecewise((0, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 - R**2*deltaRHeadz*zetaPara*zetaRatio*Piecewise((0, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 - R**2*deltaRHeadz*zetaPara*Piecewise((0, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 + R**2*deltaRHeadz*zetaPara*Piecewise((0, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 - R**2*deltaRHelixz*zetaPara*zetaRatio*Piecewise((0, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 + R**2*deltaRHelixz*zetaPara*zetaRatio*Piecewise((0, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 + R**2*deltaRHelixz*zetaPara*Piecewise((0, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 - R**2*deltaRHelixz*zetaPara*Piecewise((0, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 + R**2*rHelixz*zetaPara*zetaRatio*Piecewise((0, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 - R**2*rHelixz*zetaPara*zetaRatio*Piecewise((0, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 - R**2*rHelixz*zetaPara*Piecewise((0, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 + R**2*rHelixz*zetaPara*Piecewise((0, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 + R*deltaRHeady*l**2*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(2*pi) - R*deltaRHeady*l**2*zetaPara*sin(alpha)*cos(alpha)/(2*pi) - R*deltaRHelixy*l**2*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(2*pi) + R*deltaRHelixy*l**2*zetaPara*sin(alpha)*cos(alpha)/(2*pi) + R*l**2*rHelixy*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(2*pi) - R*l**2*rHelixy*zetaPara*sin(alpha)*cos(alpha)/(2*pi) + deltaRHeadz*l*zetaPara*zetaRatio - deltaRHelixz*l*zetaPara*zetaRatio + l*rHelixz*zetaPara*zetaRatio, -R*deltaRHeadz*l**2*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(2*pi) + R*deltaRHeadz*l**2*zetaPara*sin(alpha)*cos(alpha)/(2*pi) + R*deltaRHelixz*l**2*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(2*pi) - R*deltaRHelixz*l**2*zetaPara*sin(alpha)*cos(alpha)/(2*pi) - R*l**2*rHelixz*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(2*pi) + R*l**2*rHelixz*zetaPara*sin(alpha)*cos(alpha)/(2*pi) + deltaRHeady*l**3*zetaPara*zetaRatio*cos(alpha)**2/12 - deltaRHeady*l**3*zetaPara*cos(alpha)**2/12 - deltaRHeady*l*zetaPara*zetaRatio - deltaRHelixy*l**3*zetaPara*zetaRatio*cos(alpha)**2/12 + deltaRHelixy*l**3*zetaPara*cos(alpha)**2/12 + deltaRHelixy*l*zetaPara*zetaRatio + l**3*rHelixy*zetaPara*zetaRatio*cos(alpha)**2/12 - l**3*rHelixy*zetaPara*cos(alpha)**2/12 - l*rHelixy*zetaPara*zetaRatio,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# [-R**2*deltaRHeadz*zetaPara*zetaRatio*Piecewise((-l/2, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 + R**2*deltaRHeadz*zetaPara*zetaRatio*Piecewise((l/2, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 + R**2*deltaRHeadz*zetaPara*Piecewise((-l/2, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 - R**2*deltaRHeadz*zetaPara*Piecewise((l/2, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 + R**2*deltaRHelixz*zetaPara*zetaRatio*Piecewise((-l/2, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 - R**2*deltaRHelixz*zetaPara*zetaRatio*Piecewise((l/2, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 - R**2*deltaRHelixz*zetaPara*Piecewise((-l/2, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 + R**2*deltaRHelixz*zetaPara*Piecewise((l/2, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 - R**2*rHelixz*zetaPara*zetaRatio*Piecewise((-l/2, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 + R**2*rHelixz*zetaPara*zetaRatio*Piecewise((l/2, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 + R**2*rHelixz*zetaPara*Piecewise((-l/2, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 - R**2*rHelixz*zetaPara*Piecewise((l/2, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 - deltaRHeadz*l*zetaPara*zetaRatio + deltaRHelixz*l*zetaPara*zetaRatio - l*rHelixz*zetaPara*zetaRatio,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        -R*deltaRHeadx*l**2*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(2*pi) + R*deltaRHeadx*l**2*zetaPara*sin(alpha)*cos(alpha)/(2*pi) + R*deltaRHelixx*l**2*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(2*pi) - R*deltaRHelixx*l**2*zetaPara*sin(alpha)*cos(alpha)/(2*pi) - R*l**2*rHelixx*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(2*pi) + R*l**2*rHelixx*zetaPara*sin(alpha)*cos(alpha)/(2*pi),                                                                                                                                                                                                                                                                                                                                                                                           -deltaRHeadx*l**3*zetaPara*zetaRatio*cos(alpha)**2/12 + deltaRHeadx*l**3*zetaPara*cos(alpha)**2/12 + deltaRHeadx*l*zetaPara*zetaRatio + deltaRHelixx*l**3*zetaPara*zetaRatio*cos(alpha)**2/12 - deltaRHelixx*l**3*zetaPara*cos(alpha)**2/12 - deltaRHelixx*l*zetaPara*zetaRatio - l**3*rHelixx*zetaPara*zetaRatio*cos(alpha)**2/12 + l**3*rHelixx*zetaPara*cos(alpha)**2/12 + l*rHelixx*zetaPara*zetaRatio,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# [ R**2*deltaRHeady*zetaPara*zetaRatio*Piecewise((-l/2, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 - R**2*deltaRHeady*zetaPara*zetaRatio*Piecewise((l/2, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 - R**2*deltaRHeady*zetaPara*Piecewise((-l/2, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 + R**2*deltaRHeady*zetaPara*Piecewise((l/2, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 - R**2*deltaRHelixy*zetaPara*zetaRatio*Piecewise((-l/2, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 + R**2*deltaRHelixy*zetaPara*zetaRatio*Piecewise((l/2, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 + R**2*deltaRHelixy*zetaPara*Piecewise((-l/2, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 - R**2*deltaRHelixy*zetaPara*Piecewise((l/2, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 + R**2*rHelixy*zetaPara*zetaRatio*Piecewise((-l/2, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 - R**2*rHelixy*zetaPara*zetaRatio*Piecewise((l/2, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 - R**2*rHelixy*zetaPara*Piecewise((-l/2, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 + R**2*rHelixy*zetaPara*Piecewise((l/2, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 + deltaRHeady*l*zetaPara*zetaRatio - deltaRHelixy*l*zetaPara*zetaRatio + l*rHelixy*zetaPara*zetaRatio,                                                                                                                                                                                                                                                                                                                                                                                          -R**2*deltaRHeadx*zetaPara*zetaRatio*Piecewise((0, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 + R**2*deltaRHeadx*zetaPara*zetaRatio*Piecewise((0, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 + R**2*deltaRHeadx*zetaPara*Piecewise((0, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 - R**2*deltaRHeadx*zetaPara*Piecewise((0, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 + R**2*deltaRHelixx*zetaPara*zetaRatio*Piecewise((0, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 - R**2*deltaRHelixx*zetaPara*zetaRatio*Piecewise((0, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 - R**2*deltaRHelixx*zetaPara*Piecewise((0, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 + R**2*deltaRHelixx*zetaPara*Piecewise((0, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 - R**2*rHelixx*zetaPara*zetaRatio*Piecewise((0, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 + R**2*rHelixx*zetaPara*zetaRatio*Piecewise((0, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 + R**2*rHelixx*zetaPara*Piecewise((0, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 - R**2*rHelixx*zetaPara*Piecewise((0, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 - deltaRHeadx*l*zetaPara*zetaRatio + deltaRHelixx*l*zetaPara*zetaRatio - l*rHelixx*zetaPara*zetaRatio,                                                                                                                                                                                                                                                                                                                                                                                                              R*deltaRHeadx*l**2*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(2*pi) - R*deltaRHeadx*l**2*zetaPara*sin(alpha)*cos(alpha)/(2*pi) - R*deltaRHelixx*l**2*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(2*pi) + R*deltaRHelixx*l**2*zetaPara*sin(alpha)*cos(alpha)/(2*pi) + R*l**2*rHelixx*zetaPara*zetaRatio*sin(alpha)*cos(alpha)/(2*pi) - R*l**2*rHelixx*zetaPara*sin(alpha)*cos(alpha)/(2*pi), R**2*deltaRHeadx*deltaRHeadz*zetaPara*zetaRatio*Piecewise((0, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 - R**2*deltaRHeadx*deltaRHeadz*zetaPara*zetaRatio*Piecewise((0, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 - R**2*deltaRHeadx*deltaRHeadz*zetaPara*Piecewise((0, Eq(2*pi/l, 0)), (-l/4, True))*sin(alpha)**2 + R**2*deltaRHeadx*deltaRHeadz*zetaPara*Piecewise((0, Eq(2*pi/l, 0)), (l/4, True))*sin(alpha)**2 - R**2*deltaRHeadx*deltaRHelixz*zetaPara*zetaRatio*Piecewi ...

# %%
systemMatrix = zi.subs(l,1)
systemMatrix = systemMatrix.row_join(-ai.subs(l,1))
solve_linear_system(systemMatrix, vHeadx, vHeady, vHeadz, wHeadx, wHeady, wHeadz)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-a9873ee767f9> in <module>()
#       1 systemMatrix = zi.subs(l,1)
#       2 systemMatrix = systemMatrix.row_join(-ai.subs(l,1))
# ----> 3 solve_linear_system(systemMatrix, vHeadx, vHeady, vHeadz, wHeadx, wHeady, wHeadz)
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/solvers/solvers.py in solve_linear_system(system, *symbols, **flags)
#    2152             if do_simplify:
#    2153                 for k, v in rv.items():
# -> 2154                     rv[k] = simplify(v)
#    2155             if not all(i.is_zero for i in rv.values()):
#    2156                 # non-trivial solution
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, fu)
#     543     expr = bottom_up(expr, lambda w: w.normal())
#     544     expr = Mul(*powsimp(expr).as_content_primitive())
# --> 545     _e = cancel(expr)
#     546     expr1 = shorter(_e, _mexpand(_e).cancel())  # issue 6829
#     547     expr2 = shorter(together(expr, deep=True), together(expr1, deep=True))
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/polys/polytools.py in cancel(f, *gens, **args)
#    6329
#    6330     try:
# -> 6331         (F, G), opt = parallel_poly_from_expr((p, q), *gens, **args)
#    6332     except PolificationFailed:
#    6333         if not isinstance(f, (tuple, Tuple)):
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/polys/polytools.py in parallel_poly_from_expr(exprs, *gens, **args)
#    4166     """Construct polynomials from expressions. """
#    4167     opt = options.build_options(gens, args)
# -> 4168     return _parallel_poly_from_expr(exprs, opt)
#    4169
#    4170
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/polys/polytools.py in _parallel_poly_from_expr(exprs, opt)
#    4205
#    4206                 if opt.expand:
# -> 4207                     expr = expr.expand()
#    4208         else:
#    4209             failed = True
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/core/expr.py in expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    2960             if use_hint:
#    2961                 hint = '_eval_expand_' + hint
# -> 2962                 expr, hit = Expr._expand_hint(expr, hint, deep=deep, **hints)
#    2963
#    2964         while True:
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    2893             sargs = []
#    2894             for arg in expr.args:
# -> 2895                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2896                 hit |= arghit
#    2897                 sargs.append(arg)
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    2893             sargs = []
#    2894             for arg in expr.args:
# -> 2895                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2896                 hit |= arghit
#    2897                 sargs.append(arg)
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    2893             sargs = []
#    2894             for arg in expr.args:
# -> 2895                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2896                 hit |= arghit
#    2897                 sargs.append(arg)
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    2893             sargs = []
#    2894             for arg in expr.args:
# -> 2895                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2896                 hit |= arghit
#    2897                 sargs.append(arg)
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    2893             sargs = []
#    2894             for arg in expr.args:
# -> 2895                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2896                 hit |= arghit
#    2897                 sargs.append(arg)
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    2893             sargs = []
#    2894             for arg in expr.args:
# -> 2895                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2896                 hit |= arghit
#    2897                 sargs.append(arg)
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    2901
#    2902         if hasattr(expr, hint):
# -> 2903             newexpr = getattr(expr, hint)(**hints)
#    2904             if newexpr != expr:
#    2905                 return (newexpr, True)
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/core/mul.py in _eval_expand_mul(self, **hints)
#     823                         t = t._eval_expand_mul()
#     824                     args.append(t)
# --> 825                 return Add(*args)
#     826             else:
#     827                 return plain
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/core/operations.py in __new__(cls, *args, **options)
#      39             return args[0]
#      40
# ---> 41         c_part, nc_part, order_symbols = cls.flatten(args)
#      42         is_commutative = not nc_part
#      43         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/core/add.py in flatten(cls, seq)
#     256
#     257         # order args canonically
# --> 258         _addsort(newseq)
#     259
#     260         # current code expects coeff to be first
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/core/add.py in _addsort(args)
#      16 def _addsort(args):
#      17     # in-place sorting of args
# ---> 18     args.sort(key=_args_sortkey)
#      19
#      20
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/core/basic.py in compare(self, other)
#     188             r = Basic(*r) if isinstance(r, frozenset) else r
#     189             if isinstance(l, Basic):
# --> 190                 c = l.compare(r)
#     191             else:
#     192                 c = (l > r) - (l < r)
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/core/basic.py in compare(self, other)
#     180         #
#     181         st = self._hashable_content()
# --> 182         ot = other._hashable_content()
#     183         c = (len(st) > len(ot)) - (len(st) < len(ot))
#     184         if c:
#
# /Users/gabriel/anaconda/lib/python3.6/site-packages/sympy/core/numbers.py in _hashable_content(self)
#    1358
#    1359     def _hashable_content(self):
# -> 1360         return (self.p, self.q)
#    1361
#    1362     def _eval_is_positive(self):
#
# KeyboardInterrupt:

# %%
ai.shape
# Out:
# (6, 1)
